# %%
import pandas as pd
df=pd.read_csv('data.csv')

# %%
#Understanding the data - summary of each feature
df.count()
# Out:
# Unnamed: 0         315
# price              308
# type               315
# address            315
# url                315
# agent_url          311
# postcode           184
# number_bedrooms    304
# search_date        315
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0      price                                       type  \
# 0           0   164950.0  2 bedroom semi-detached bungalow for sale
# 1           1        NaN          6 bedroom detached house for sale
# 2           2        NaN          6 bedroom detached house for sale
# 3           3  2000000.0      5 bedroom character property for sale
# 4           4  1420000.0          6 bedroom detached house for sale
#
#                                              address  \
# 0                   Grinstead Way, Carrville, Durham
# 1            Flass Vale Hall, Crossgate Moor, Durham
# 2            Flass Vale Hall, Crossgate Moor, Durham
# 3                          Durham House, Durham, DH1
# 4  Oakland House, West Rainton, Houghton le Sprin...
#
#                                                  url  \
# 0  http://www.rightmove.co.uk/properties/11883042...
# 1  http://www.rightmove.co.uk/properties/96987176...
# 2  http://www.rightmove.co.uk/properties/84542365...
# 3  http://www.rightmove.co.uk/properties/10624343...
# 4  http://www.rightmove.co.uk/properties/12005870...
#
#                                            agent_url postcode  \
# 0  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 1  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 2  http://www.rightmove.co.uk/estate-agents/agent...      NaN
# 3  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 4  http://www.rightmove.co.uk/estate-agents/agent...      NaN
#
#    number_bedrooms                 search_date
# 0              2.0  2022-02-19 17:56:03.021236
# 1              6.0  2022-02-19 17:56:03.021236
# 2              6.0  2022-02-19 17:56:03.021236
# 3              5.0  2022-02-19 17:56:03.021236
# 4              6.0  2022-02-19 17:56:03.021236

# %%
df = df.dropna()
df
#df.describe()
# Out:
#      Unnamed: 0      price                                   type  \
# 3             3  2000000.0  5 bedroom character property for sale
# 6             6   995000.0      6 bedroom detached house for sale
# 7             7   895000.0      4 bedroom detached house for sale
# 10           10   775000.0               4 bedroom house for sale
# 11           11   745000.0            5 bedroom bungalow for sale
# ..          ...        ...                                    ...
# 302         302    70000.0                1 bedroom flat for sale
# 306         306    65000.0      2 bedroom terraced house for sale
# 308         308    63000.0           1 bedroom apartment for sale
# 309         309    62000.0      2 bedroom terraced house for sale
# 313         313    40000.0                1 bedroom flat for sale
#
#                                          address  \
# 3                      Durham House, Durham, DH1
# 6            Beckwood, Potters Bank, Durham, DH1
# 7                      Aykley Heads, Durham, DH1
# 10                         Hartside, Durham, DH1
# 11     Western Cottage, Whitesmocks, Durham, DH1
# ..                                           ...
# 302           Bamburgh Road, Durham, Durham, DH1
# 306  John Street South, Meadowfield, Durham, DH7
# 308                   Bamburgh Road, Durham, DH1
# 309  Edward Terrace, New Brancepeth, Durham, DH7
# 313                                  Durham, DH1
#
#                                                    url  \
# 3    http://www.rightmove.co.uk/properties/10624343...
# 6    http://www.rightmove.co.uk/properties/11999281...
# 7    http://www.rightmove.co.uk/properties/11994159...
# 10   http://www.rightmove.co.uk/properties/10704632...
# 11   http://www.rightmove.co.uk/properties/10840439...
# ..                                                 ...
# 302  http://www.rightmove.co.uk/properties/11639111...
# 306  http://www.rightmove.co.uk/properties/11818157...
# 308  http://www.rightmove.co.uk/properties/75307341...
# 309  http://www.rightmove.co.uk/properties/11957458...
# 313  http://www.rightmove.co.uk/properties/11994319...
#
#                                              agent_url postcode  \
# 3    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 6    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 7    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 10   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 11   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# ..                                                 ...      ...
# 302  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 306  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 308  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 309  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 313  http://www.rightmove.co.uk/estate-agents/agent...      DH1
#
#      number_bedrooms                 search_date
# 3                5.0  2022-02-19 17:56:03.021236
# 6                6.0  2022-02-19 17:56:03.021236
# 7                4.0  2022-02-19 17:56:03.021236
# 10               4.0  2022-02-19 17:56:03.021236
# 11               5.0  2022-02-19 17:56:03.021236
# ..               ...                         ...
# 302              1.0  2022-02-19 17:56:03.021236
# 306              2.0  2022-02-19 17:56:03.021236
# 308              1.0  2022-02-19 17:56:03.021236
# 309              2.0  2022-02-19 17:56:03.021236
# 313              1.0  2022-02-19 17:56:03.021236
#
# [169 rows x 9 columns]

# %%
result = re.search('bedroom (.*) for sale', s)
df[['Building']] = df.type.str.split(" ",expand=True,)
df
# Out:
# Unnamed: 0         315
# price              308
# type               315
# address            315
# url                315
# agent_url          311
# postcode           184
# number_bedrooms    304
# search_date        315
# dtype: int64

# %%
import re
df["building"] = "hi"
for index, row in df.iterrows():
    result = ( re.search('bedroom (.*) for sale', row["type"]).group(1))
    df.loc[index,'building'] = result
# Out:
#      Unnamed: 0      price                                   type  \
# 3             3  2000000.0  5 bedroom character property for sale
# 6             6   995000.0      6 bedroom detached house for sale
# 7             7   895000.0      4 bedroom detached house for sale
# 10           10   775000.0               4 bedroom house for sale
# 11           11   745000.0            5 bedroom bungalow for sale
# ..          ...        ...                                    ...
# 302         302    70000.0                1 bedroom flat for sale
# 306         306    65000.0      2 bedroom terraced house for sale
# 308         308    63000.0           1 bedroom apartment for sale
# 309         309    62000.0      2 bedroom terraced house for sale
# 313         313    40000.0                1 bedroom flat for sale
#
#                                          address  \
# 3                      Durham House, Durham, DH1
# 6            Beckwood, Potters Bank, Durham, DH1
# 7                      Aykley Heads, Durham, DH1
# 10                         Hartside, Durham, DH1
# 11     Western Cottage, Whitesmocks, Durham, DH1
# ..                                           ...
# 302           Bamburgh Road, Durham, Durham, DH1
# 306  John Street South, Meadowfield, Durham, DH7
# 308                   Bamburgh Road, Durham, DH1
# 309  Edward Terrace, New Brancepeth, Durham, DH7
# 313                                  Durham, DH1
#
#                                                    url  \
# 3    http://www.rightmove.co.uk/properties/10624343...
# 6    http://www.rightmove.co.uk/properties/11999281...
# 7    http://www.rightmove.co.uk/properties/11994159...
# 10   http://www.rightmove.co.uk/properties/10704632...
# 11   http://www.rightmove.co.uk/properties/10840439...
# ..                                                 ...
# 302  http://www.rightmove.co.uk/properties/11639111...
# 306  http://www.rightmove.co.uk/properties/11818157...
# 308  http://www.rightmove.co.uk/properties/75307341...
# 309  http://www.rightmove.co.uk/properties/11957458...
# 313  http://www.rightmove.co.uk/properties/11994319...
#
#                                              agent_url postcode  \
# 3    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 6    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 7    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 10   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 11   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# ..                                                 ...      ...
# 302  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 306  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 308  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 309  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 313  http://www.rightmove.co.uk/estate-agents/agent...      DH1
#
#      number_bedrooms                 search_date            building
# 3                5.0  2022-02-19 17:56:03.021236  character property
# 6                6.0  2022-02-19 17:56:03.021236      detached house
# 7                4.0  2022-02-19 17:56:03.021236      detached house
# 10               4.0  2022-02-19 17:56:03.021236               house
# 11               5.0  2022-02-19 17:56:03.021236            bungalow
# ..               ...                         ...                 ...
# 302              1.0  2022-02-19 17:56:03.021236                flat
# 306              2.0  2022-02-19 17:56:03.021236      terraced house
# 308              1.0  2022-02-19 17:56:03.021236           apartment
# 309              2.0  2022-02-19 17:56:03.021236      terraced house
# 313              1.0  2022-02-19 17:56:03.021236                flat
#
# [169 rows x 10 columns]

# %%
df['building']. value_counts()
# Out:
# semi-detached house       41
# terraced house            33
# detached house            32
# flat                      19
# apartment                 11
# bungalow                   9
# end of terrace house       8
# detached bungalow          5
# house                      3
# town house                 2
# character property         2
# semi-detached bungalow     1
# retirement property        1
# ground floor flat          1
# barn conversion            1
# Name: building, dtype: int64

# %%
for index, row in df.iterrows():
    if (row["building"])=="semi-detached house":
        df.loc[index,'building'] = 1
    elif (row["building"])=="terraced house":
        df.loc[index,'building'] = 2
    elif (row["building"])=="detached house":
        df.loc[index,'building'] = 3
    elif (row["building"])=="flat":
        df.loc[index,'building'] = 4
    elif (row["building"])=="apartment":
        df.loc[index,'building'] = 5
    elif (row["building"])=="bungalow":
        df.loc[index,'building'] = 6
    elif (row["building"])=="end of terrace house":
        df.loc[index,'building'] = 7
    elif (row["building"])=="detached bungalow":
        df.loc[index,'building'] = 8
    elif (row["building"])=="house":
        df.loc[index,'building'] = 9
    elif (row["building"])=="town house":
        df.loc[index,'building'] = 10
    elif (row["building"])=="character property":
        df.loc[index,'building'] = 11
    elif (row["building"])=="semi-detached bungalow":
        df.loc[index,'building'] = 12
    elif (row["building"])=="retirement property":
        df.loc[index,'building'] = 13
    elif (row["building"])=="ground floor flat":
        df.loc[index,'building'] = 14
    elif (row["building"])=="barn conversion":
        df.loc[index,'building'] = 15
df
# Out:
#      Unnamed: 0      price                                   type  \
# 3             3  2000000.0  5 bedroom character property for sale
# 6             6   995000.0      6 bedroom detached house for sale
# 7             7   895000.0      4 bedroom detached house for sale
# 10           10   775000.0               4 bedroom house for sale
# 11           11   745000.0            5 bedroom bungalow for sale
# ..          ...        ...                                    ...
# 302         302    70000.0                1 bedroom flat for sale
# 306         306    65000.0      2 bedroom terraced house for sale
# 308         308    63000.0           1 bedroom apartment for sale
# 309         309    62000.0      2 bedroom terraced house for sale
# 313         313    40000.0                1 bedroom flat for sale
#
#                                          address  \
# 3                      Durham House, Durham, DH1
# 6            Beckwood, Potters Bank, Durham, DH1
# 7                      Aykley Heads, Durham, DH1
# 10                         Hartside, Durham, DH1
# 11     Western Cottage, Whitesmocks, Durham, DH1
# ..                                           ...
# 302           Bamburgh Road, Durham, Durham, DH1
# 306  John Street South, Meadowfield, Durham, DH7
# 308                   Bamburgh Road, Durham, DH1
# 309  Edward Terrace, New Brancepeth, Durham, DH7
# 313                                  Durham, DH1
#
#                                                    url  \
# 3    http://www.rightmove.co.uk/properties/10624343...
# 6    http://www.rightmove.co.uk/properties/11999281...
# 7    http://www.rightmove.co.uk/properties/11994159...
# 10   http://www.rightmove.co.uk/properties/10704632...
# 11   http://www.rightmove.co.uk/properties/10840439...
# ..                                                 ...
# 302  http://www.rightmove.co.uk/properties/11639111...
# 306  http://www.rightmove.co.uk/properties/11818157...
# 308  http://www.rightmove.co.uk/properties/75307341...
# 309  http://www.rightmove.co.uk/properties/11957458...
# 313  http://www.rightmove.co.uk/properties/11994319...
#
#                                              agent_url postcode  \
# 3    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 6    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 7    http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 10   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 11   http://www.rightmove.co.uk/estate-agents/agent...      DH1
# ..                                                 ...      ...
# 302  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 306  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 308  http://www.rightmove.co.uk/estate-agents/agent...      DH1
# 309  http://www.rightmove.co.uk/estate-agents/agent...      DH7
# 313  http://www.rightmove.co.uk/estate-agents/agent...      DH1
#
#      number_bedrooms                 search_date building
# 3                5.0  2022-02-19 17:56:03.021236        1
# 6                6.0  2022-02-19 17:56:03.021236        3
# 7                4.0  2022-02-19 17:56:03.021236        3
# 10               4.0  2022-02-19 17:56:03.021236        9
# 11               5.0  2022-02-19 17:56:03.021236        6
# ..               ...                         ...      ...
# 302              1.0  2022-02-19 17:56:03.021236        4
# 306              2.0  2022-02-19 17:56:03.021236        2
# 308              1.0  2022-02-19 17:56:03.021236        5
# 309              2.0  2022-02-19 17:56:03.021236        2
# 313              1.0  2022-02-19 17:56:03.021236        4
#
# [169 rows x 10 columns]

# %%
df['postcode']. value_counts()
# Out:
# DH1    98
# DH7    48
# DH6    15
# DH4     7
# DH2     1
# Name: postcode, dtype: int64

# %%
for index, row in df.iterrows():
    if (row["postcode"])=="DH1":
        df.loc[index,'postcode'] = 1
    elif (row["postcode"])=="DH2":
        df.loc[index,'postcode'] = 2
    elif (row["postcode"])=="DH7":
        df.loc[index,'postcode'] = 7
    elif (row["postcode"])=="DH6":
        df.loc[index,'postcode'] = 6
    elif (row["postcode"])=="DH4":
        df.loc[index,'postcode'] = 4
df
# Out:
#      Unnamed: 0      price                                   type  \
# 3             3  2000000.0  5 bedroom character property for sale
# 6             6   995000.0      6 bedroom detached house for sale
# 7             7   895000.0      4 bedroom detached house for sale
# 10           10   775000.0               4 bedroom house for sale
# 11           11   745000.0            5 bedroom bungalow for sale
# ..          ...        ...                                    ...
# 302         302    70000.0                1 bedroom flat for sale
# 306         306    65000.0      2 bedroom terraced house for sale
# 308         308    63000.0           1 bedroom apartment for sale
# 309         309    62000.0      2 bedroom terraced house for sale
# 313         313    40000.0                1 bedroom flat for sale
#
#                                          address  \
# 3                      Durham House, Durham, DH1
# 6            Beckwood, Potters Bank, Durham, DH1
# 7                      Aykley Heads, Durham, DH1
# 10                         Hartside, Durham, DH1
# 11     Western Cottage, Whitesmocks, Durham, DH1
# ..                                           ...
# 302           Bamburgh Road, Durham, Durham, DH1
# 306  John Street South, Meadowfield, Durham, DH7
# 308                   Bamburgh Road, Durham, DH1
# 309  Edward Terrace, New Brancepeth, Durham, DH7
# 313                                  Durham, DH1
#
#                                                    url  \
# 3    http://www.rightmove.co.uk/properties/10624343...
# 6    http://www.rightmove.co.uk/properties/11999281...
# 7    http://www.rightmove.co.uk/properties/11994159...
# 10   http://www.rightmove.co.uk/properties/10704632...
# 11   http://www.rightmove.co.uk/properties/10840439...
# ..                                                 ...
# 302  http://www.rightmove.co.uk/properties/11639111...
# 306  http://www.rightmove.co.uk/properties/11818157...
# 308  http://www.rightmove.co.uk/properties/75307341...
# 309  http://www.rightmove.co.uk/properties/11957458...
# 313  http://www.rightmove.co.uk/properties/11994319...
#
#                                              agent_url postcode  \
# 3    http://www.rightmove.co.uk/estate-agents/agent...        1
# 6    http://www.rightmove.co.uk/estate-agents/agent...        1
# 7    http://www.rightmove.co.uk/estate-agents/agent...        1
# 10   http://www.rightmove.co.uk/estate-agents/agent...        1
# 11   http://www.rightmove.co.uk/estate-agents/agent...        1
# ..                                                 ...      ...
# 302  http://www.rightmove.co.uk/estate-agents/agent...        1
# 306  http://www.rightmove.co.uk/estate-agents/agent...        7
# 308  http://www.rightmove.co.uk/estate-agents/agent...        1
# 309  http://www.rightmove.co.uk/estate-agents/agent...        7
# 313  http://www.rightmove.co.uk/estate-agents/agent...        1
#
#      number_bedrooms                 search_date building
# 3                5.0  2022-02-19 17:56:03.021236        1
# 6                6.0  2022-02-19 17:56:03.021236        3
# 7                4.0  2022-02-19 17:56:03.021236        3
# 10               4.0  2022-02-19 17:56:03.021236        9
# 11               5.0  2022-02-19 17:56:03.021236        6
# ..               ...                         ...      ...
# 302              1.0  2022-02-19 17:56:03.021236        4
# 306              2.0  2022-02-19 17:56:03.021236        2
# 308              1.0  2022-02-19 17:56:03.021236        5
# 309              2.0  2022-02-19 17:56:03.021236        2
# 313              1.0  2022-02-19 17:56:03.021236        4
#
# [169 rows x 10 columns]

# %%
#Model
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
#features = ['postcode','number_bedrooms','building']
features = ['number_bedrooms','building']
X = df[features]
Y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=40)
linear_model =  LinearRegression(normalize=True)
linear_model.fit(X,Y) 

LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
coef = linear_model.coef_
intercept = linear_model.intercept_

linear_pred = linear_model.predict(X)

corr_matrix = np.corrcoef(Y, linear_pred)
corr = corr_matrix[0,1]
R_sq = corr**2
 
print(R_sq)
# Out:
# 0.46515066441109304

# %%
print(X)
# Out:
#      number_bedrooms building
# 3                5.0        1
# 6                6.0        3
# 7                4.0        3
# 10               4.0        9
# 11               5.0        6
# ..               ...      ...
# 302              1.0        4
# 306              2.0        2
# 308              1.0        5
# 309              2.0        2
# 313              1.0        4
#
# [169 rows x 2 columns]

# %%
linear_pred = linear_model.predict([[5,2]])

# %%
linear_pred[0]
# Out:
# 543742.6554398965
